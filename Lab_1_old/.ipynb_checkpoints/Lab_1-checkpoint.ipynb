% %% [markdown]
% <h1>Table of Contents<span class="tocSkip"></span></h1>
% <div class="toc"><ul class="toc-item"><li><span><a href="#Challenge" data-toc-modified-id="Challenge-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Challenge</a></span></li><li><span><a href="#Component-level-measurements" data-toc-modified-id="Component-level-measurements-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Component-level measurements</a></span><ul class="toc-item"><li><span><a href="#Measuring-Resistance-of-Electrical-Components" data-toc-modified-id="Measuring-Resistance-of-Electrical-Components-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Measuring Resistance of Electrical Components</a></span></li><li><span><a href="#Measuring-Resistance-of-the-Human-Body" data-toc-modified-id="Measuring-Resistance-of-the-Human-Body-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Measuring Resistance of the Human Body</a></span></li></ul></li><li><span><a href="#System-of-Resistors" data-toc-modified-id="System-of-Resistors-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>System of Resistors</a></span><ul class="toc-item"><li><span><a href="#Voltage" data-toc-modified-id="Voltage-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Voltage</a></span></li><li><span><a href="#Current" data-toc-modified-id="Current-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Current</a></span></li></ul></li></ul></div>

% %% [markdown]
% # Challenge
%
% In ES103 you developed the ability to model dynamic systems and predict their behavior.  By the end of Lab 2, you will need to use that knowledge to explain the behavior of an unfamiliar electrical system shown below.  To be able to make modeling decisions, as you did in ES103, you'll need data that describes how both the compoments and system behaves to be able to do both model scoping and construction.  In order to explain how this system works, you are going to need to learn some data aquistion and measurement techniques.

% %% [markdown]
% ![image-2.png](attachment:image-2.png)

% %% [markdown]
% # Component-level measurements
%
% We'll begin by applying the same methodology as before and begin with Model scoping.  Considering the components first, some of them may be familiar: the voltage source and resistor.  The guitar "pickup" is a device used on electrical guitars to detect or "pickup" the vibrations of the strings.  It allows the physical vibration of the strings to be converted into an oscillating electrical signal.  That is helpful information, but it doesn't tell us how this system we'll behave as part of the electrical system defined by the circuit diagram above.  So, let's begin with what we know.
%
% You have have worked with a model for resistors in ES103. The [model you developed](../../ES103/Resource/Resource.ipynb#Ohm's-Law) for electrical resistors requires you know a "resistance" value.  To meet this lab's challenge, you'll need to make measurements of resistance using your [ Digital MultiMeter (DMM)](../Lab_1_Resources/Lab1_Hardware_resource.ipynb#Multimeter)

% %% [markdown]
% ## Measuring Resistance of Electrical Components
%
% Using Ohm's Law, the multimeter applies a known current and measures the resulting voltage drop in order to calculate and display the resistance of the component.

% %% [markdown]
% You can practice this measurement by comparing your measured resistance to the nominal value of an electrical resistor provided by the manufacturer.  Because resistors are often too small to print a number on them, a standard color code is used which consists of four color bands. With just those four bands you can determine the resistance to 2 significant digits as well as the manufacturing tolerance.
%
% 1.	Use the [color-coding scheme](../Lab_1_Resources/Lab1_Hardware_resource.ipynb#Resistor-Color-Codes), find resistors with nominal values of 1$k\Omega$, 2$k\Omega$, 5$k\Omega$, and 10$k\Omega$ resistors.
% 2.	Use your multimeter to measure the resistance of the same resistors. Create a table comparing the measured resistance values with those you obtained using the color coding.
% 3.	Verify that the measured resistance values are within the tolerance limits by calculating the percent error, $E_\%$, between the manufacturer reported value and the actual measured value.
% 4.	Document your results in the table below
%
% Note. When you applied the [first law to a resistor](../../ES103/Reading_11/Reading_11.ipynb#Ohm's-Law) you established that resistors are dispitative elements that converts electrial work to heat transfer.... <font color='red'>THAT MEANS THEY CAN GET HOT!</font>
%
% Typical resistors we use in the lab are rated 0.25 watt, but [higher power resistors exist](../Lab_1_Resources/Lab1_Hardware_resource.ipynb#High-Power-Resistors). <font color='red'> With enough power, the temperature of a resistor can rise to very high levels and might cause burns </font>. This is the principle of an incandescent light bulb, where the temperature of the filament rises thousands of degrees.  The components you will be using in this class are rated for the power supplies you are using, **but if components do get too hot to touch, disconnect the power supply and contact your instructor!**

% %% [markdown]
% $$E_\% = \left|\frac{R_{reported}-R_{meas}}{R_{meas}}\right|$$

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% ## Measuring Resistance of the Human Body
%
% The model for electrical resistance does not apply to just electrical components.  Your body can also be modeled as a disipative element and characterized by the resistance property.
%
% Let's see what applying the resistance model to your body reveals.  Begin by measuring the resistance between a short distance by pinching the probes of the DMM between your fingers.

% %% [markdown]
% ![image-2.png](attachment:image-2.png)

% %% [markdown]
% Record the lowest value observed while applying moderate pressure. Repeat taking this measurement 5 times.  Now hold the one probe in each hand, making sure to pinch each probe to make good contact.  Repeat  Document these data and calculations in the table below. Note that $\sigma$ stands for standard deviation, the formula for which is given below:
%
% $$\sigma = \sqrt{\frac{\sum{(x_i-\mu)^2}}{N}}$$
%
% Where $x_i$ are all of your measurements, $\mu$ is the mean of the population, and $N$ is the population size.

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% In your own words, interpret the formula above explain what "standard deviation" or $\sigma$ **means**.

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% What physical explanation would you provide to explain what happens to resistance when you measured it across a short distance and a long distance?

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% # System of Resistors
%
% You have modeling experience predicting the response of a network of resistors.  Let's expand your measurement capabilities in an effort to do model validation.

% %% [markdown]
% ## Voltage

% %% [markdown]
% ![image-4.png](attachment:image-4.png)

% %% [markdown]
% Using the the $1k\Omega$  and  $2k\Omega$ resistors, construct the circuit above using your breadboard [LINK]
%
% 1.	[Connect your 5-volt power source to the breadboard](../Lab_1_Resources/Lab1_Hardware_resource.ipynb#Breadboard)
% 2.  Insert resistors into the breadboard and the 5V and ground "bus" (see link above)
% 3.	[Use the DMM](../Lab_1_Resources/Lab1_Hardware_resource.ipynb#Multimeter) to measure the voltage source, $V_s$, and the voltage across each resistor, $V_{R1}$ and $V_{R2}$. Record these measurements in the table below.
% 4.	Using previous knowledge about [resistors](../ES103/Reading_11/Reading_11.ipynb) and about [analyzing electrical systems](../ES103/Reading_14/Reading_14.ipynb#The-Principle-of-Compatibility-(Kirchoff's-Voltage-Law)), Develop a relationship and calculate the expected voltage across resistor $V_{R2}$ using the *measured* values of $V_{R1}$ and $V_{R2}$.  Put your work in the Markdown cell below.

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% Every voltmeter has an internal resistance. Would you expect a good voltmeter to have a low or high internal resistance? Why?

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% Measure the resistance of $R_2$ within the circuit with the 5V applied and list your measurement below.  Considering how the DMM is measuring resistance, do you expect this to be an accurate measurement?

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% ## Current

% %% [markdown]
% ![image-2.png](attachment:image-2.png)

% %% [markdown]
% 1.	Construct the circuit as shown in the figure above on a breadboard.
% 2.	Properly connect the DMM with the circuit to [measure the currents](../Lab_1_Resources/Week01_Hardware_resource.ipynb#Measuring-Current-Using-a-Multimeter) $I_s$, $I_1$, and $I_2$ one at a time. Record these measurements in the table below.

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% 3.	[Using your knowledge of electrical systems](../ES103/Resource/Resource.ipynb#The-Principle-of-Compatibility-(Kirchoff's-Voltage-Law)), determine the predicted values of $I_s$,$I_1$, and $I_2$.

% %% [markdown]
% YOUR ANSWER HERE

% %% [markdown]
% 4.	Every current meter has an internal resistance. Would you expect a good current meter to have a low or high internal resistance? Why?

% %% [markdown]
% YOUR ANSWER HERE
